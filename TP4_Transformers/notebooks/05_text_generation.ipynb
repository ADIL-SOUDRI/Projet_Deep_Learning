# %%
# import torch
# from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "t5-small"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

print("T5 model loaded successfully")
# Out:
# T5 model loaded successfully

# %%
prompt = "summarize: Deep learning is"

inputs = tokenizer(prompt, return_tensors="pt", truncation=True)

output = model.generate(
    **inputs,
    max_length=60,
    repetition_penalty=1.2
)

# %%
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

print(generated_text)
# Out:
# Deep learning is a deep learning tool that can help you learn more about the world.

# %%
prompts = [
    "summarize: Artificial intelligence will",
    "summarize: The future of AI is",
    "summarize: Transformers are"
]

for p in prompts:
    inputs = tokenizer(p, return_tensors="pt", truncation=True)

    with torch.no_grad():
        output = model.generate(
            **inputs,
            max_length=40,
            repetition_penalty=1.2
        )

    print("\nPrompt:", p)
    print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# Prompt: summarize: Artificial intelligence will
# artificial intelligence will be used to identify the best possible targets for the u.
#
# Prompt: summarize: The future of AI is
# the future of AI is a new challenge for AI.
#
# Prompt: summarize: Transformers are
# Transformers are

# %%
# generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

# print(generated_text)
# Out:
# Deep learning is a great way to learn about the world and how we can help you.
# The best part of this course, if it's not for your own personal gain or any other reason, will be that there are many different ways in which students have access to information on their lives as well

# %%
# prompts = [
#     "Artificial intelligence will",
#     "The future of AI is",
#     "Transformers are"
# ]

# for p in prompts:
#     inputs = tokenizer(p, return_tensors="pt")

#     output = model.generate(
#         **inputs,
#         max_length=40,
#         temperature=0.8
#     )

#     print("\nPrompt:", p)
#     print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Prompt: Artificial intelligence will
# Artificial intelligence will be able to predict the future of the world, and it will be able to predict the future of the world.
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Prompt: The future of AI is
# The future of AI is not yet clear.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Prompt: Transformers are
# Transformers are a great way to get your hands on a new game.
