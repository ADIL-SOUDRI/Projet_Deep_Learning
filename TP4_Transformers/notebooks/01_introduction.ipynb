# %% [markdown]
# 🔹 Section 1 — Titre & objectif
#
# Tu expliques :
#
# Qu’est-ce qu’un Transformer ?
# Pourquoi on l’utilise ?
# Objectif du notebook
# 🔹 Section 2 — Théorie simple
#
# Tu dois expliquer (en markdown) :
#
# Tokenization
# Embeddings
# Attention mechanism
# Pourquoi Transformers > RNN/LSTM
#
# 👉 Pas de code ici, seulement explication.
#
# 🔹 Section 3 — Tokenizer
#
# Objectif :
#
# comprendre comment un texte devient des tokens
#
# 👉 Tu testes avec plusieurs phrases :
#
# phrase simple
# phrase complexe
# phrase multilingue
# 🔹 Section 4 — Modèle pré-entraîné
#
# Objectif :
#
# charger un modèle Transformer déjà entraîné (ex: BERT ou DistilBERT)
#
# Tu dois comprendre :
#
# input → tokens
# output → vecteurs
# 🔹 Section 5 — Test simple forward pass
#
# Objectif :
#
# voir comment le modèle transforme le texte
#
# Tu observes :
#
# shape des outputs
# représentation des mots
# 🔹 Section 6 — Analyse des résultats
#
# Tu expliques :
#
# ce que représente chaque sortie
# différence entre tokens et embeddings
# rôle du [CLS] token
# 🔹 Section 7 — Conclusion
#
# Tu résumes :
#
# ce que tu as compris
# limites
# préparation pour classification TP4
