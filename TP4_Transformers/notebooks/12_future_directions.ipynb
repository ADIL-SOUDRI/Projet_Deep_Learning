# %%
# Affichage d'un titre pour la section
print("=== FUTURE OF TRANSFORMERS ===")

# Affichage d'une phrase explicative sur les Transformers
print("Transformers are the foundation of modern AI systems.")
# Out:
# === FUTURE OF TRANSFORMERS ===
# Transformers are the foundation of modern AI systems.

# %%
# Liste des grands modèles de langage (LLMs)
llms = [
    "GPT-4 / GPT-5",
    "LLaMA models",
    "Claude models",
    "Mistral models"
]

# Affichage de chaque modèle de langage
for m in llms:
    print("LLM:", m)
# Out:
# LLM: GPT-4 / GPT-5
# LLM: LLaMA models
# LLM: Claude models
# LLM: Mistral models

# %%
# Liste des différentes modalités des modèles multimodaux
modalities = [
    "Text + Image (CLIP)",
    "Text + Audio",
    "Text + Video",
    "Vision Transformers (ViT)"
]

# Affichage des différentes modalités
for m in modalities:
    print("Multimodal:", m)
# Out:
# Multimodal: Text + Image (CLIP)
# Multimodal: Text + Audio
# Multimodal: Text + Video
# Multimodal: Vision Transformers (ViT)

# %%
# Liste des limitations des modèles d'IA modernes
limits = [
    "High computation cost",
    "Memory consumption",
    "Hallucination problems",
    "Need for large datasets",
    "Lack of reasoning reliability"
]

# Affichage de chaque limitation
for l in limits:
    print("Limitation:", l)
# Out:
# Limitation: High computation cost
# Limitation: Memory consumption
# Limitation: Hallucination problems
# Limitation: Need for large datasets
# Limitation: Lack of reasoning reliability

# %%
# Liste des tendances futures en intelligence artificielle et modèles de langage
future = [
    "Smaller efficient LLMs",
    "On-device AI (mobile AI)",
    "Better reasoning models",
    "Real-time multimodal systems",
    "AI agents (autonomous systems)"
]

# Affichage des tendances futures
for f in future:
    print("Future trend:", f)
# Out:
# Future trend: Smaller efficient LLMs
# Future trend: On-device AI (mobile AI)
# Future trend: Better reasoning models
# Future trend: Real-time multimodal systems
# Future trend: AI agents (autonomous systems)
